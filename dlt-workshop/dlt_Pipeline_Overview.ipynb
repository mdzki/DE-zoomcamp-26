# %% [markdown]
# ## 📦 Step 0: Install Dependencies

# %%
# install dependencies first
# !pip -q install dlt[duckdb]

# %% [markdown]
# <p>In this notebook we will use:</p>
#
# <ul>
#   <li><strong>dlt</strong> to extract, normalize, and load data</li>
#   <li><strong>DuckDB</strong> as the destination database (runs locally inside Colab)</li>
# </ul>
#
# <p>
#   DuckDB is great for beginners because it requires no setup and no credentials.
# </p>

# %% [markdown]
# ## 📚 Step 1: Import Libraries

# %% [markdown]
# <p>In this cell we import the libraries we will use throughout the notebook:</p>
#
# <ul>
#   <li><strong>dlt</strong> is the main library for building and running the pipeline</li>
#   <li><strong>rest_api_source</strong> helps us define an API source using a simple configuration</li>
#   <li><strong>islice</strong> (from <code>itertools</code>) is a small Python helper for previewing only a few records</li>
# </ul>

# %%
import dlt
import dlt
from itertools import islice
from dlt.sources.rest_api import rest_api_source

# %% [markdown]
# ## 🔗 Step 2: Define the API Source (Open Library)

# %% [markdown]
# <p>
#   In <strong>dlt</strong>, a <strong>source</strong> is the part of your pipeline that knows how to fetch data from somewhere.
#   In this notebook, our source fetches data from the <strong>Open Library Search API</strong>.
# </p>
#
# <p>
#   We define the source using <code>rest_api_source</code>, which lets us describe an API in a simple
#   Python dictionary instead of writing lots of request code.
# </p>
#
# <p>
#   📖 <strong>Open Library Search API docs:</strong><br>
#   <a href="https://openlibrary.org/dev/docs/api/search" target="_blank">
#     https://openlibrary.org/dev/docs/api/search
#   </a>
# </p>

# %%
def openlibrary_source(query: str = "harry potter"):

    return rest_api_source({
        "client": {
            "base_url": "https://openlibrary.org",
        },
        "resource_defaults": {
            "primary_key": "key",
            "write_disposition": "replace",
        },
        "resources": [
            {
                "name": "books",
                "endpoint": {
                    "path": "search.json",
                    "params": {
                        "q": query,
                        "limit": 100,
                    },
                    "data_selector": "docs",
                    "paginator": {
                        "type": "offset",
                        "limit": 100,
                        "offset_param": "offset",
                        "limit_param": "limit",
                        "total_path": "numFound",
                    },
                },
            },
        ],
    })

# %% [markdown]
# ## 🔧 Step 3: Create the dlt Pipeline

# %%
pipeline = dlt.pipeline(
    pipeline_name="ol_demo",
    destination="duckdb",
    dataset_name="ol_data",
    progress="log" # logs the pipeline run (Optiona)
)

# %% [markdown]
# ## 🔍 Understanding the Pipeline
#
# At this point we have defined two key building blocks:
#
# - **The source** describes where the data comes from and how to fetch it from the API.
# - **The pipeline** describes where the data should go (DuckDB) and keeps track of tables, schemas, and run history.
#
# ---
#
# Instead of running everything at once, we will now run the pipeline in three separate phases so you can clearly see what happens at each stage:
#
# 1. **Extract**: download raw data from the API
# 2. **Normalize**: turn nested JSON into relational tables
# 3. **Load**: write those tables into DuckDB

# %% [markdown]
# ![ETL Diagram](https://github.com/anair123/data-engineering-zoomcamp/blob/workshop/dlt_2026/cohorts/2026/workshops/dlt/images/etl_diagram.png?raw=1)

# %% [markdown]
# Once these steps make sense, we will run the full workflow again using one command:
#
# ```python
# pipeline.run(source)

# %% [markdown]
# ## ⬇️ Step 4: Extract
#
# Now we run the first stage of the pipeline: **Extract**.
#
# Extract means:
#
# - dlt sends requests to the Open Library API
# - the raw JSON responses are downloaded
# - the results are stored in dlt’s local working folder
#
# At this stage, the data is **not** in DuckDB yet. We are just confirming that we successfully pulled data from the API.

# %%
extract_info = pipeline.extract(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 202.76 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 1.93s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 20971520.00/s
# Memory usage: 205.87 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 3.22s | Rate: 0.00/s
# books: 300  | Time: 1.29s | Rate: 233.26/s
# Memory usage: 206.29 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 4.41s | Rate: 0.00/s
# books: 400  | Time: 2.48s | Rate: 161.24/s
# Memory usage: 206.38 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 5.89s | Rate: 0.00/s
# books: 500  | Time: 3.96s | Rate: 126.24/s
# Memory usage: 206.72 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 7.45s | Rate: 0.00/s
# books: 600  | Time: 5.52s | Rate: 108.63/s
# Memory usage: 207.21 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 9.03s | Rate: 0.00/s
# books: 800  | Time: 7.10s | Rate: 112.64/s
# Memory usage: 207.80 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 10.25s | Rate: 0.00/s
# books: 900  | Time: 8.32s | Rate: 108.11/s
# Memory usage: 208.12 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 11.28s | Rate: 0.00/s
# books: 1000  | Time: 9.35s | Rate: 106.92/s
# Memory usage: 208.49 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 13.39s | Rate: 0.00/s
# books: 1200  | Time: 11.46s | Rate: 104.67/s
# Memory usage: 209.11 MB (31.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 14.84s | Rate: 0.00/s
# books: 1300  | Time: 12.91s | Rate: 100.66/s
# Memory usage: 209.11 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 16.05s | Rate: 0.00/s
# books: 1400  | Time: 14.12s | Rate: 99.13/s
# Memory usage: 209.11 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 18.01s | Rate: 0.00/s
# books: 1600  | Time: 16.08s | Rate: 99.48/s
# Memory usage: 209.16 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 20.33s | Rate: 0.00/s
# books: 1800  | Time: 18.40s | Rate: 97.80/s
# Memory usage: 209.57 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 22.32s | Rate: 0.00/s
# books: 2000  | Time: 20.39s | Rate: 98.07/s
# Memory usage: 210.22 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 23.33s | Rate: 0.00/s
# books: 2100  | Time: 21.40s | Rate: 98.15/s
# Memory usage: 210.56 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 24.62s | Rate: 0.00/s
# books: 2300  | Time: 22.69s | Rate: 101.39/s
# Memory usage: 211.35 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 26.57s | Rate: 0.00/s
# books: 2500  | Time: 24.64s | Rate: 101.47/s
# Memory usage: 212.11 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 28.57s | Rate: 0.00/s
# books: 2700  | Time: 26.64s | Rate: 101.37/s
# Memory usage: 212.90 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 30.11s | Rate: 0.00/s
# books: 2800  | Time: 28.18s | Rate: 99.37/s
# Memory usage: 213.27 MB (32.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 31.36s | Rate: 0.00/s
# books: 2900  | Time: 29.43s | Rate: 98.52/s
# Memory usage: 213.67 MB (32.10%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 33.43s | Rate: 0.00/s
# books: 3100  | Time: 31.50s | Rate: 98.40/s
# Memory usage: 214.46 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 35.01s | Rate: 0.00/s
# books: 3200  | Time: 33.08s | Rate: 96.74/s
# Memory usage: 214.87 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 36.48s | Rate: 0.00/s
# books: 3300  | Time: 34.55s | Rate: 95.51/s
# Memory usage: 215.28 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 37.68s | Rate: 0.00/s
# books: 3400  | Time: 35.75s | Rate: 95.10/s
# Memory usage: 215.69 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 39.74s | Rate: 0.00/s
# books: 3500  | Time: 37.81s | Rate: 92.56/s
# Memory usage: 216.18 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 42.00s | Rate: 0.00/s
# books: 3700  | Time: 40.07s | Rate: 92.33/s
# Memory usage: 217.04 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 43.10s | Rate: 0.00/s
# books: 3759  | Time: 41.17s | Rate: 91.31/s
# Memory usage: 217.36 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 43.12s | Rate: 0.02/s
# books: 3759  | Time: 41.19s | Rate: 91.25/s
# Memory usage: 218.71 MB (31.90%) | CPU usage: 0.00%

# %% [markdown]
# ---
#
# ### What we will print
#
# After extraction, we will print a small summary showing:
#
# - which **resources** were extracted
# - which **tables** will be created later
# - how many rows were extracted per resource
#
# This helps confirm that the pipeline is working before we move on to normalization.

# %%
load_id = extract_info.loads_ids[-1]
m = extract_info.metrics[load_id][0]

print("Resources:", list(m["resource_metrics"].keys()))
print("Tables:", list(m["table_metrics"].keys()))
print("Load ID:", load_id)
print()

for resource, rm in m["resource_metrics"].items():
    print(f"Resource: {resource}")
    print(f"rows extracted: {rm.items_count}")
    print()
# Out:
# Resources: ['books']
# Tables: ['books']
# Load ID: 1772472653.1065857
#
# Resource: books
# rows extracted: 3759

# %% [markdown]
# ### What you should see after Extract
#
# In our case, Extract shows only **one resource and one table**:
#
# - **Resources:** `['books']`
# - **Tables:** `['books']`
#
# That is expected.
#
# The `search` endpoint returns a list of book results, so dlt stores those rows in a single table called `books`. The interesting part comes next, because many fields inside each row are lists or nested objects. Those will turn into additional tables during **Normalize**.
#
# Example output:
#
# - **25 rows extracted** means we pulled 25 search results (books)
#
# ---

# %% [markdown]
# ## 🔄 Step 5: Normalize
#
# Now we run **Normalize**. This is where dlt transforms raw JSON into a clean relational structure.
#
# During normalization, dlt does three key things:
#
# ### 1. Adds Tracking Columns to the Main Table
#
# dlt adds special columns to every table:
# - `_dlt_id`: A unique identifier for each row
# - `_dlt_load_id`: Links each row to the load job that created it
#
# ### 2. Flattens Nested Data into Child Tables
#
# APIs often return nested JSON. For example, a book can have multiple authors (a list), multiple editions, and multiple identifiers.
#
# dlt flattens these nested structures into separate **child tables** with names like:
# - `books__author_name`
# - `books__author_key`
# - `books__language`
#
# Each child table has a `_dlt_parent_id` column that references `_dlt_id` in the parent table. This is how dlt maintains relationships.
#
# ### 3. Creates Metadata Tables
#
# dlt also creates internal tables to track pipeline state:
# - `_dlt_loads`: Tracks load history (when data was loaded, status)
# - `_dlt_pipeline_state`: Stores pipeline state for incremental loading
# - `_dlt_version`: Tracks schema versions
#
# In the next cell, we will print a summary showing which tables were created.

# %%
normalize_info = pipeline.normalize()
# Out:
# ------------------- Normalize rest_api in 1772472653.1065857 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 219.78 MB (32.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772472653.1065857 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 219.78 MB (32.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772472653.1065857 -------------------
# Files: 9/1 (900.0%) | Time: 0.18s | Rate: 49.62/s
# Items: 23083  | Time: 0.18s | Rate: 127363.46/s
# Memory usage: 232.31 MB (32.00%) | CPU usage: 0.00%

# %%
print(f"loads_ids content: {normalize_info.loads_ids}")
print(f"loads_ids length: {len(normalize_info.loads_ids)}")
# Out:
# loads_ids content: ['1772472653.1065857']
# loads_ids length: 1

# %%
load_id = normalize_info.loads_ids[-1]
m = normalize_info.metrics[load_id][0]

print("Load ID:", load_id)
print()

print("Tables created/updated:")
for table_name, tm in m["table_metrics"].items():
    # skip dlt internal tables to keep it beginner-friendly
    if table_name.startswith("_dlt"):
        continue
    print(f"  - {table_name}: {tm.items_count} rows")
# Out:
# Load ID: 1772472653.1065857
#
# Tables created/updated:
#   - books: 3759 rows
#   - books__author_key: 4637 rows
#   - books__author_name: 4637 rows
#   - books__ia: 3435 rows
#   - books__ia_collection: 2735 rows
#   - books__language: 3748 rows
#   - books__id_standard_ebooks: 12 rows
#   - books__id_librivox: 64 rows
#   - books__id_project_gutenberg: 56 rows

# %% [markdown]
# ### What happened during Normalize?
#
# After running `pipeline.normalize()`, we now see multiple tables instead of just one.
#
# Tables created/updated:
#
# - `books`
# - `books__author_key`
# - `books__author_name`
# - `books__editions__docs`
# - `books__editions__docs__language`
# - `books__ia`
#
# ---
#
# ### What does this mean?
#
# We started with **N book search results** in the `books` table.
#
# During normalization:
#
# - Each book may have **more than N authors**, so those were split into:
#   - `books__author_name`
#   - `books__author_key`
#
# - Each book may contain **edition information**, which became:
#   - `books__editions__docs`
#
# - Some editions contain **language information**, which became:
#   - `books__editions__docs__language`
#
# - The `ia` field (Internet Archive IDs) is a list, so it became:
#   - `books__ia`
#
# This is the key moment in the pipeline.
#
# The data has been transformed from nested JSON into a **relational structure** with multiple linked tables. This makes it much easier to query and analyze.
#
# ---
#
# ### Schema Visualization
#
# dlt can render the schema as a visual diagram. Run the next cell to see the parent-child table relationships:

# %% [markdown]
# # Building a Data Pipeline with dlt
#
# In this notebook, we will build a complete data pipeline from scratch using **dlt**.
#
# Our goal is simple:
#
# → Fetch real data from an API
# → Turn it into clean relational tables
# → Load it into a database
# → Explore and analyze it
#
# We will use the **Open Library API** as our data source and **DuckDB** as our database.
#
# Along the way, you will learn:
#
# - What a dlt source is
# - What a dlt pipeline does
# - How data moves through Extract → Normalize → Load
# - How to inspect and explore the final dataset
#
# By the end, you will understand not just how to run a pipeline, but what happens at each stage.

# %%
# Display schema
pipeline.default_schema
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Display schema
# ----> 2 pipeline.default_schema
#
# NameError: name 'pipeline' is not defined

# %% [markdown]
# ## 📤 Step 6: Load
#
# Now we run the final stage of the pipeline: **Load**.
#
# Load means:
#
# - dlt creates tables in DuckDB (if they do not already exist)
# - the normalized rows are inserted into those tables
# - the pipeline records the load in its internal tracking tables

# %%
load_info = pipeline.load()
# Out:
# --------------------- Load rest_api in 1772312103.0559146 ----------------------
# Jobs: 0/10 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 258.05 MB (30.40%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772312103.0559146 ----------------------
# Jobs: 10/10 (100.0%) | Time: 0.28s | Rate: 35.53/s
# Memory usage: 283.03 MB (30.70%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1772318738.807648 ----------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 283.04 MB (30.70%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1772318738.807648 ----------------------
# Jobs: 9/9 (100.0%) | Time: 0.30s | Rate: 30.39/s
# Memory usage: 289.53 MB (31.00%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772319311.8224833 ----------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 289.53 MB (31.00%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772319311.8224833 ----------------------
# Jobs: 9/9 (100.0%) | Time: 0.28s | Rate: 31.80/s
# Memory usage: 291.56 MB (31.10%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772471543.4804573 ----------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 291.56 MB (31.10%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772471543.4804573 ----------------------
# Jobs: 9/9 (100.0%) | Time: 0.28s | Rate: 32.60/s
# Memory usage: 292.57 MB (31.00%) | CPU usage: 0.00%

# %% [markdown]
# After this step, the data is fully stored in the database and ready to query.
#
# At this point:
#
# - The `books` table contains our books
# - The related tables (such as `books__author_name` and `books__editions__docs`) contain the exploded nested data
# - Everything is now queryable using `pipeline.dataset()` or SQL
#
# This is the moment where the data officially moves from “pipeline processing” into a database you can explore.

# %% [markdown]
# ## 🚀 Step 7: Run the Full Pipeline
#
# Now that we have walked through each step individually, we can run the entire workflow using a single command:

# %%
load_info = pipeline.run(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 280.99 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 5.54s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 29959314.29/s
# Memory usage: 280.99 MB (30.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 7.65s | Rate: 0.00/s
# books: 300  | Time: 2.12s | Rate: 141.77/s
# Memory usage: 280.99 MB (30.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 9.05s | Rate: 0.00/s
# books: 400  | Time: 3.51s | Rate: 113.98/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 10.47s | Rate: 0.00/s
# books: 500  | Time: 4.93s | Rate: 101.38/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 12.40s | Rate: 0.00/s
# books: 600  | Time: 6.86s | Rate: 87.43/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 13.57s | Rate: 0.00/s
# books: 700  | Time: 8.03s | Rate: 87.16/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 14.61s | Rate: 0.00/s
# books: 800  | Time: 9.08s | Rate: 88.14/s
# Memory usage: 280.99 MB (30.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 16.91s | Rate: 0.00/s
# books: 1000  | Time: 11.37s | Rate: 87.95/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 18.06s | Rate: 0.00/s
# books: 1100  | Time: 12.53s | Rate: 87.81/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 19.31s | Rate: 0.00/s
# books: 1200  | Time: 13.77s | Rate: 87.14/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 20.70s | Rate: 0.00/s
# books: 1300  | Time: 15.16s | Rate: 85.76/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 22.73s | Rate: 0.00/s
# books: 1500  | Time: 17.20s | Rate: 87.23/s
# Memory usage: 280.99 MB (30.50%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 24.72s | Rate: 0.00/s
# books: 1700  | Time: 19.18s | Rate: 88.64/s
# Memory usage: 280.99 MB (30.70%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 26.93s | Rate: 0.00/s
# books: 1900  | Time: 21.39s | Rate: 88.83/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 27.94s | Rate: 0.00/s
# books: 2000  | Time: 22.40s | Rate: 89.27/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 29.15s | Rate: 0.00/s
# books: 2100  | Time: 23.61s | Rate: 88.93/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 31.45s | Rate: 0.00/s
# books: 2300  | Time: 25.91s | Rate: 88.78/s
# Memory usage: 280.99 MB (30.60%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 33.47s | Rate: 0.00/s
# books: 2500  | Time: 27.93s | Rate: 89.51/s
# Memory usage: 280.99 MB (30.80%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 34.71s | Rate: 0.00/s
# books: 2600  | Time: 29.17s | Rate: 89.12/s
# Memory usage: 280.99 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 35.80s | Rate: 0.00/s
# books: 2700  | Time: 30.27s | Rate: 89.21/s
# Memory usage: 280.99 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 37.10s | Rate: 0.00/s
# books: 2800  | Time: 31.56s | Rate: 88.71/s
# Memory usage: 280.99 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 38.51s | Rate: 0.00/s
# books: 2900  | Time: 32.97s | Rate: 87.95/s
# Memory usage: 280.99 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 40.37s | Rate: 0.00/s
# books: 3000  | Time: 34.83s | Rate: 86.12/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 41.92s | Rate: 0.00/s
# books: 3100  | Time: 36.38s | Rate: 85.20/s
# Memory usage: 281.00 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 44.14s | Rate: 0.00/s
# books: 3200  | Time: 38.60s | Rate: 82.90/s
# Memory usage: 281.00 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 45.65s | Rate: 0.00/s
# books: 3300  | Time: 40.12s | Rate: 82.26/s
# Memory usage: 281.00 MB (30.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 47.14s | Rate: 0.00/s
# books: 3400  | Time: 41.60s | Rate: 81.73/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 48.71s | Rate: 0.00/s
# books: 3500  | Time: 43.18s | Rate: 81.06/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 50.38s | Rate: 0.00/s
# books: 3600  | Time: 44.84s | Rate: 80.28/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 51.57s | Rate: 0.00/s
# books: 3700  | Time: 46.03s | Rate: 80.38/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 52.80s | Rate: 0.00/s
# books: 3759  | Time: 47.26s | Rate: 79.53/s
# Memory usage: 281.00 MB (31.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 52.83s | Rate: 0.02/s
# books: 3759  | Time: 47.29s | Rate: 79.49/s
# Memory usage: 281.57 MB (31.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772471627.9684136 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 281.57 MB (31.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772471627.9684136 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 281.57 MB (31.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1772471627.9684136 -------------------
# Files: 9/1 (900.0%) | Time: 0.18s | Rate: 49.69/s
# Items: 23083  | Time: 0.18s | Rate: 127532.24/s
# Memory usage: 285.55 MB (31.00%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772471627.9684136 ----------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 285.55 MB (31.00%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1772471627.9684136 ----------------------
# Jobs: 9/9 (100.0%) | Time: 0.28s | Rate: 31.60/s
# Memory usage: 289.32 MB (31.00%) | CPU usage: 0.00%

# %% [markdown]
# <h3>What does <code>pipeline.run()</code> do?</h3>
#
# <p>
#   <code>pipeline.run()</code> simply combines the three steps we already executed manually:
# </p>
#
# <ol>
#   <li><strong>Extract</strong> – fetch data from the Open Library API</li>
#   <li><strong>Normalize</strong> – convert nested JSON into relational tables</li>
#   <li><strong>Load</strong> – write those tables into DuckDB</li>
# </ol>
#
# <p>In other words, this:</p>
#
# <pre><code>pipeline.run(source)</code></pre>
#
# <p>is equivalent to:</p>
#
# <pre><code>pipeline.extract(source)
# pipeline.normalize()
# pipeline.load()</code></pre>
#
# <p>
#   There is no hidden magic. It just runs the full ELT process in order.
# </p>

# %% [markdown]
# ## 🔎 Step 8: Inspect the Loaded Data
#
# Now that the data is loaded into DuckDB, we can inspect it using `pipeline.dataset()`.
#
# This gives us a convenient Python interface for exploring the tables that dlt created, without writing SQL.
#
# ---
#
# ### List available tables
#
# First, let’s see what tables exist in the dataset:

# %%
ds = pipeline.dataset()

# %%
ds.tables
# Out:
# ['books',
#  'books__author_key',
#  'books__author_name',
#  'books__ia',
#  'books__ia_collection',
#  'books__language',
#  'books__id_standard_ebooks',
#  'books__id_librivox',
#  'books__id_project_gutenberg',
#  '_dlt_version',
#  '_dlt_loads',
#  '_dlt_pipeline_state']

# %%
df = ds.books.df()      # main table
df.head(3)
# Out:
#   cover_edition_key   cover_i   ebook_access  edition_count  \
# 0       OL61027601M  15155833     borrowable            397
# 1       OL26378158M  15158660  printdisabled            144
# 2       OL26234270M  10580435     borrowable            279
#
#    first_publish_year  has_fulltext              key lending_edition_s  \
# 0                1997          True  /works/OL82563W       OL38565767M
# 1                2007          True  /works/OL82586W               NaN
# 2                1999          True  /works/OL82536W       OL48101764M
#
#             lending_identifier_s  public_scan_b  \
# 0  harrypotterylapi0000rowl_q5r6          False
# 1                            NaN          False
# 2                 bdrc-W8LS66814          False
#
#                                       title        _dlt_load_id  \
# 0  Harry Potter and the Philosopher's Stone  1772471627.9684136
# 1      Harry Potter and the Deathly Hallows  1772471627.9684136
# 2  Harry Potter and the Prisoner of Azkaban  1772471627.9684136
#
#           _dlt_id subtitle
# 0  KDHpv3jeLa3uDg      NaN
# 1  4wCzCZLvawDQKA      NaN
# 2  /AWDefZa5gMEMQ      NaN

# %% [markdown]
# ## 💡 Conclusion
#
# ### What dlt handled for us
#
# ✔ API requests
# ✔ JSON normalization
# ✔ Table creation
# ✔ Database loading
# ✔ Simple dataset inspection
#
# ---
#
# ### But there are still friction points
#
# • Getting the REST API config exactly right
# • Remembering paginator syntax
# • Remembering how to inspect tables
# • Debugging schema or pagination issues
# • Writing Python or SQL to get insights
#
# It works... but it still takes effort.
#
# ---
#
# ## 🚀 Next Up: LLM-Powered Workflows
#
# dlt now integrates LLMs directly into the workflow to make:
#
# • Pipeline runs easier
# • Debugging faster
# • Schema inspection simpler
# • Data analysis more natural
#
# Instead of writing glue code, you can use natural language.
#
# In the workshop, we will see what that looks like.
